# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
duq=pd.read_sas('DUQ_H.XPT')
huq=pd.read_sas('HUQ_H.XPT')
nsduh=pd.read_csv('NSDUH-2014.csv')

# %%
df=huq.merge(duq, how='inner', on='SEQN')

# %%
col_list=
corr=df.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
plt.show()

# %% [markdown]
# NHANES
# DUQ210 - age when first tried mj
# DUQ200 - ever used marijuana
# DUQ211 - used every mo for a yr?

# %%
in_hosp=nsduh[nsduh['NMNGTHS2']<990]

# %%
corr=in_hosp.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
plt.show()

# %%
DUQ320
